# %%
import requests
import numpy as np
from matplotlib import pyplot as plt
import sys
import os
import math

# %%
current_dir = os.path.dirname(os.path.abspath('examples'))
sys.path.append(os.path.join(current_dir, 'robotiq'))
from utils.UR_Functions import URfunctions as URControl
from robotiq.robotiq_gripper import RobotiqGripper

# %%
def degreestorad(list):
     for i in range(6):
          list[i]=list[i]*(math.pi/180)
     return(list)

# %%
robot = URControl(ip="192.168.0.2", port=30003)
gripper=RobotiqGripper()
gripper.connect("192.168.0.2", 63352)
gripper.activate()
# Out:
# Connected to robot
# Gripper auto-calibrated to [3, 248]

# %%
#move to start state
gripper.move(0,125,125)
joint_state = [0.00000744, -1.57083954, 1.57082969, -1.57077511, -1.57079918, -0.00003463]
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)

# %%
#move and pick up vial 1
joint_state = degreestorad([-5.61,-83.95,112.70,-119.79,-90.07,-5.48])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
gripper.move(255,125,125)
joint_state = degreestorad([-5.61,-88.51,105.96,-107.5,-90.03,-5.53])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)

# %%
#pick up vial 2
joint_state = degreestorad([-1.37,-83.69,111.69,-118.03,-90.07,-1.24])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
gripper.move(255,125,125)
joint_state = [-0.02380783, -1.53301641,  1.81360704, -1.85189833, -1.57132942, -0.02249176]
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)

# %%
print(robot.get_current_joint_positions().tolist())
# Out:
# [-0.06971866 -1.50937307  1.84992677 -1.94247594 -1.57164127 -0.06830389]

# %%
#place vial 1 in slot 2
joint_state = degreestorad([-1.36,-88.22,102.71,-104.52,-90.03,-1.29])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
joint_state = degreestorad([-1.37,-83.69,111.69,-118.03,-90.07,-1.24])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
gripper.move(0,125,125)
# Out:
# (True, 3)

# %%
#placevial2 in slot 1
joint_state = [0.00000744, -1.57083954, 1.57082969, -1.57077511, -1.57079918, -0.00003463]
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
joint_state = degreestorad([-5.61,-83.95,112.70,-119.79,-90.07,-5.48])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
gripper.move(0,125,125)
joint_state = degreestorad([-5.61,-88.51,105.96,-107.5,-90.03,-5.53])
robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 5
#       3 robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
#       4 joint_state = degreestorad([-5.61,-83.95,112.70,-119.79,-90.07,-5.48])
# ----> 5 robot.move_joint_list(joint_state, 0.25, 0.5, 0.02)
#       6 gripper.move(0,125,125)
#       7 joint_state = degreestorad([-5.61,-88.51,105.96,-107.5,-90.03,-5.53])
#
# File ~/ctl-ur5-robot-tools/examples/utils/UR_Functions.py:104, in URfunctions.move_joint_list(self, q, v, a, r)
#     102 tcp_command += "end\n"
#     103 self.sk.send(str.encode(tcp_command))
# --> 104 self.wait_for_target_joints(q)
#     105 self.close_connection()
#
# File ~/ctl-ur5-robot-tools/examples/utils/UR_Functions.py:110, in URfunctions.wait_for_target_joints(self, target_joints, tol)
#     108 actual_joints = self.get_current_joint_positions()
#     109 while not all(np.abs(actual_joints - np.array(target_joints)) < tol):
# --> 110     sleep(0.1)
#     111     actual_joints = self.get_current_joint_positions()
#
# KeyboardInterrupt:
